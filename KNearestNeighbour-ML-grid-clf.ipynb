# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('Social_Network_Ads.csv')
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype='int')
dataset.drop('User ID',axis=1)
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
dataset['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
indep=dataset[['Gender_Male','Age','EstimatedSalary']]
dep=dataset[['Purchased']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=0.30,random_state=0)
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
param_grid={'n_neighbors':[5,7],'weights':['uniform','distance'],'algorithm':['auto','kd_tree','ball_tree','brute'],'p':[1,2],'metric':['minkowski']}
grid=GridSearchCV(KNeighborsClassifier(),param_grid,refit=True,verbose=3,n_jobs=-1,scoring='f1_weighted')
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# C:\Anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# GridSearchCV(estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['auto', 'kd_tree', 'ball_tree', 'brute'],
#                          'metric': ['minkowski'], 'n_neighbors': [5, 7],
#                          'p': [1, 2], 'weights': ['uniform', 'distance']},
#              scoring='f1_weighted', verbose=3)

# %%
result=grid.cv_results_
grid_prediction=grid.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_prediction)
print('confusion matrix:\n',cm)
# Out:
# confusion matrix:
#  [[73  6]
#  [ 4 37]]

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(y_test,grid_prediction)
print('The clf report :\n',clf_report)
# Out:
# The clf report :
#                precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94        79
#            1       0.86      0.90      0.88        41
#
#     accuracy                           0.92       120
#    macro avg       0.90      0.91      0.91       120
# weighted avg       0.92      0.92      0.92       120

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_prediction,average='weighted')
print('The f1_macro value for the best parameters {}:'.format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for the best parameters {'algorithm': 'auto', 'metric': 'minkowski', 'n_neighbors': 7, 'p': 2, 'weights': 'uniform'}: 0.9171245421245421

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(x_test)[:,1])
# Out:
# 0.9424205001543686

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.007919      0.001881         0.024389        0.003524
# 1        0.008561      0.002484         0.012867        0.002331
# 2        0.007344      0.003504         0.020554        0.002819
# 3        0.005262      0.004887         0.014354        0.003735
# 4        0.007414      0.004814         0.021112        0.003663
# 5        0.003957      0.002579         0.014547        0.003369
# 6        0.000000      0.000000         0.020178        0.002016
# 7        0.004247      0.004305         0.011787        0.005686
# 8        0.003959      0.005067         0.018453        0.003193
# 9        0.005785      0.001990         0.010946        0.001288
# 10       0.005560      0.002501         0.018365        0.003545
# 11       0.002070      0.001406         0.012675        0.002241
# 12       0.003414      0.004182         0.018656        0.002398
# 13       0.009255      0.002009         0.012404        0.000232
# 14       0.004699      0.004606         0.020374        0.003377
# 15       0.002325      0.003067         0.012142        0.004058
# 16       0.004809      0.003927         0.017495        0.003926
# 17       0.002307      0.002830         0.013383        0.002834
# 18       0.003812      0.002021         0.021288        0.005409
# 19       0.003256      0.002661         0.012929        0.004546
# 20       0.005853      0.001477         0.021434        0.003110
# 21       0.005389      0.004203         0.015655        0.004621
# 22       0.008368      0.004828         0.020262        0.007927
# 23       0.007954      0.001527         0.012346        0.001718
# 24       0.003300      0.003562         0.111877        0.086332
# 25       0.002179      0.004357         0.081183        0.068309
# 26       0.007186      0.006264         0.076247        0.071641
# 27       0.002851      0.003537         0.075837        0.071848
# 28       0.004108      0.005426         0.114765        0.089408
# 29       0.001414      0.001731         0.079125        0.075895
# 30       0.002430      0.002063         0.078003        0.074130
# 31       0.000815      0.001630         0.134992        0.078566
#
#    param_algorithm param_metric param_n_neighbors param_p param_weights  \
# 0             auto    minkowski                 5       1       uniform
# 1             auto    minkowski                 5       1      distance
# 2             auto    minkowski                 5       2       uniform
# 3             auto    minkowski                 5       2      distance
# 4             auto    minkowski                 7       1       uniform
# 5             auto    minkowski                 7       1      distance
# 6             auto    minkowski                 7       2       uniform
# 7             auto    minkowski                 7       2      distance
# 8          kd_tree    minkowski                 5       1       uniform
# 9          kd_tree    minkowski                 5       1      distance
# 10         kd_tree    minkowski                 5       2       uniform
# 11         kd_tree    minkowski                 5       2      distance
# 12         kd_tree    minkowski                 7       1       uniform
# 13         kd_tree    minkowski                 7       1      distance
# 14         kd_tree    minkowski                 7       2       uniform
# 15         kd_tree    minkowski                 7       2      distance
# 16       ball_tree    minkowski                 5       1       uniform
# 17       ball_tree    minkowski                 5       1      distance
# 18       ball_tree    minkowski                 5       2       uniform
# 19       ball_tree    minkowski                 5       2      distance
# 20       ball_tree    minkowski                 7       1       uniform
# 21       ball_tree    minkowski                 7       1      distance
# 22       ball_tree    minkowski                 7       2       uniform
# 23       ball_tree    minkowski                 7       2      distance
# 24           brute    minkowski                 5       1       uniform
# 25           brute    minkowski                 5       1      distance
# 26           brute    minkowski                 5       2       uniform
# 27           brute    minkowski                 5       2      distance
# 28           brute    minkowski                 7       1       uniform
# 29           brute    minkowski                 7       1      distance
# 30           brute    minkowski                 7       2       uniform
# 31           brute    minkowski                 7       2      distance
#
#                                                params  split0_test_score  \
# 0   {'algorithm': 'auto', 'metric': 'minkowski', '...           0