# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('Social_Network_Ads.csv')
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype='int')
dataset.drop('User ID',axis=1)
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
dataset['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
indep=dataset[['Gender_Male','Age','EstimatedSalary']]
dep=dataset[['Purchased']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=0.30,random_state=0)

# %%
from sklearn.naive_bayes import CategoricalNB
from sklearn.model_selection import GridSearchCV
param_grid={'alpha':[0.001,0.01,1.0], 'force_alpha':[True,'bool'], 'fit_prior':[True,'bool'],'min_categories':[None,1,3]}
grid=GridSearchCV(CategoricalNB(),param_grid,refit=True,verbose=3,n_jobs=-1,scoring='f1_weighted')
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 135 fits failed out of a total of 180.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 1378, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'force_alpha' parameter of CategoricalNB must be an instance of 'bool' or an instance of 'numpy.bool_'. Got 'bool' instead.
#
# --------------------------------------------------------------------------------
# 90 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 1378, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'fit_prior' parameter of CategoricalNB must be an instance of 'bool' or an instance of 'numpy.bool_'. Got 'bool' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=CategoricalNB(), n_jobs=-1,
#              param_grid={'alpha': [0.001, 0.01, 1.0],
#                          'fit_prior': [True, 'bool'],
#                          'force_alpha': [True, 'bool'],
#                          'min_categories': [None, 1, 3]},
#              scoring='f1_weighted', verbose=3)

# %%
result=grid.cv_results_
grid_prediction=grid.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_prediction)
print('confusion matrix:\n',cm)
# Out:
# confusion matrix:
#  [[65 14]
#  [10 31]]

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(y_test,grid_prediction)
print('The clf report :\n',clf_report)
# Out:
# The clf report :
#                precision    recall  f1-score   support
#
#            0       0.87      0.82      0.84        79
#            1       0.69      0.76      0.72        41
#
#     accuracy                           0.80       120
#    macro avg       0.78      0.79      0.78       120
# weighted avg       0.81      0.80      0.80       120

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_prediction,average='weighted')
print('The f1_macro value for the best parameters {}:'.format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for the best parameters {'alpha': 0.001, 'fit_prior': True, 'force_alpha': True, 'min_categories': None}: 0.8020537601932951

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(x_test)[:,1])
# Out:
# 0.8402284655757949

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0        0.031948      0.004639         0.029265        0.027837       0.001
# 1        0.025255      0.002878         0.028873        0.022770       0.001
# 2        0.029841      0.001982         0.016943        0.005177       0.001
# 3        0.003129      0.003837         0.000000        0.000000       0.001
# 4        0.000000      0.000000         0.000000        0.000000       0.001
# 5        0.002004      0.004008         0.000000        0.000000       0.001
# 6        0.000000      0.000000         0.000000        0.000000       0.001
# 7        0.003156      0.003762         0.000000        0.000000       0.001
# 8        0.000906      0.001812         0.000000        0.000000       0.001
# 9        0.002005      0.003307         0.000000        0.000000       0.001
# 10       0.000249      0.000499         0.000000        0.000000       0.001
# 11       0.002612      0.003822         0.000000        0.000000       0.001
# 12       0.022105      0.002166         0.015594        0.000063        0.01
# 13       0.024823      0.005630         0.015126        0.004429        0.01
# 14       0.017561      0.008428         0.012407        0.010594        0.01
# 15       0.000000      0.000000         0.000000        0.000000        0.01
# 16       0.000000      0.000000         0.000000        0.000000        0.01
# 17       0.004264      0.005456         0.000000        0.000000        0.01
# 18       0.001566      0.000937         0.000000        0.000000        0.01
# 19       0.000259      0.000518         0.000000        0.000000        0.01
# 20       0.001405      0.002809         0.000000        0.000000        0.01
# 21       0.000865      0.001729         0.000000        0.000000        0.01
# 22       0.004287      0.004851         0.000000        0.000000        0.01
# 23       0.000000      0.000000         0.000000        0.000000        0.01
# 24       0.016666      0.006154         0.006380        0.003739         1.0
# 25       0.020821      0.003174         0.004577        0.004233         1.0
# 26       0.015829      0.006364         0.007450        0.004437         1.0
# 27       0.001915      0.002598         0.000000        0.000000         1.0
# 28       0.002931      0.003975         0.000000        0.000000         1.0
# 29       0.000322      0.000644         0.000000        0.000000         1.0
# 30       0.002248      0.003916         0.000000        0.000000         1.0
# 31       0.000000      0.000000         0.000000        0.000000         1.0
# 32       0.002248      0.003916         0.000000        0.000000         1.0
# 33       0.000243      0.000487         0.000000        0.000000         1.0
# 34       0.002004      0.004008         0.000000        0.000000         1.0
# 35       0.000118      0.000236         0.000000        0.000000         1.0
#
#    param_fit_prior param_force_alpha param_min_categories  \
# 0             True              True                 None
# 1             True              True                    1
# 2             True              True                    3
# 3             True              bool                 None
# 4             True              bool                    1
# 5             True              bool                    3
# 6             bool              True                 None
# 7             bool              True                    1
# 8             bool              True                    3
# 9             bool              bool                 None
# 10            bool              bool                    1
# 11            bool              bool                    3
# 12            True              True                 None
# 13            True              True                    1
# 14            True              True                    3
# 15            True              bool                 None
# 16            True              bool                    1
# 17            True              bool                    3
# 18            bool              True                 None
# 19            bool              True                    1
# 20            bool              True                    3
# 21            bool              bool                 None
# 22            bool              bool                    1
# 23            bool              bool                    3
# 24            True              True                 None
# 25            True              True                    1
# 26            True              True                    3
# 27            True              bool                 None
# 28            True              bool                    1
# 29            True              bool                    3
# 30            bool              True                 None
# 31            bool              True                    1
# 32            bool              True                    3
# 33            bool              bool                 None
# 34            bool              bool                    1
# 35            bool              bool                    3
#
#                                                params  split0_test_score  \
# 0   {'alpha': 0.001, 'fit_prior': True, 'force_alp...           0.753521
# 1   {'alpha': 0.001, 'fit_prior': True, 'force_alp...           0.753521
# 2   {'alpha': 0.001, 'fit_prior': True, 'force_alp...           0.753521
# 3   {'alpha': 0.001, 'fit_prior': True, 'force_alp...                NaN
# 4   {'alpha': 0.001, 'fit_prior': True, 'force_alp...                NaN
# 5   {'alpha': 0.001, 'fit_prior': True, 'force_alp...                NaN
# 6   {'alpha': 0.001, 'fit_prior': 'bool', 'force_a...                NaN
# 7   {'alpha': 0.001, 'fit_prior': 'bool', 'force_a...                NaN
# 8   {'alpha': 0.001, 'fit_prior': 'bool', 'force_a...                NaN
# 9   {'alpha': 0.001, 'fit_prior': 'bool', 'force_a...                NaN
# 10  {'alpha': 0.001, 'fit_prior': 'bool', 'force_a...                NaN
# 11  {'alpha': 0.001, 'fit_prior': 'bool', 'force_a...                NaN
# 12  {'alpha': 0.01, 'fit_prior': True, 'force_alph...           0.753521
# 13  {'alpha': 0.01, 'fit_prior': True, 'force_alph...           0.753521
# 14  {'alpha': 0.01, 'fit_prior': True, 'force_alph...           0.753521
# 15  {'alpha': 0.01, 'fit_prior': True, 'force_alph...                NaN
# 16  {'alpha': 0.01, 'fit_prior': True, 'force_alph...                NaN
# 17  {'alpha': 0.01, 'fit_prior': True, 'force_alph...                NaN
# 18  {'alpha': 0.01, 'fit_prior': 'bool', 'force_al...                NaN
# 19  {'alpha': 0.01, 'fit_prior': 'bool', 'force_al...                NaN
# 20  {'alpha': 0.01, 'fit_prior': 'bool', 'force_al...                NaN
# 21  {'alpha': 0.01, 'fit_prior': 'bool', 'force_al...                NaN
# 22  {'alpha': 0.01, 'fit_prior': 'bool', 'force_al...                NaN
# 23  {'alpha': 0.01, 'fit_prior': 'bool', 'force_al...                NaN
# 24  {'alpha': 1.0, 'fit_prior': True, 'force_alpha...           0.714286
# 25  {'alpha': 1.0, 'fit_prior': True, 'force_alpha...           0.714286
# 26  {'alpha': 1.0, 'fit_prior': True, 'force_alpha...           0.714286
# 27  {'alpha': 1.0, 'fit_prior': True, 'force_alpha...                NaN
# 28  {'alpha': 1.0, 'fit_prior': True, 'force_alpha...                NaN
# 29  {'alpha': 1.0, 'fit_prior': True, 'force_alpha...                NaN
# 30  {'alpha': 1.0, 'fit_prior': 'bool', 'force_alp...                NaN
# 31  {'alpha': 1.0, 'fit_prior': 'bool', 'force_alp...                NaN
# 32  {'alpha': 1.0, 'fit_prior': 'bool', 'force_alp...                NaN
# 33  {'alpha': 1.0, 'fit_prior': 'bool', 'force_alp...                NaN
# 34  {'alpha': 1.0, 'fit_prior': 'bool', 'force_alp...                NaN
# 35  {'alpha': 1.0, 'fit_prior': 'bool', 'force_alp...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.690193           0.750000           0.836407
# 1            0.690193           0.750000           0.836407
# 2            0.690193           0.750000           0.836407
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12           0.690193           0.730543           0.816856
# 13           0.690193           0.730543           0.816856
# 14           0.690193           0.730543           0.816856
# 15                NaN                NaN                NaN
# 16                NaN                NaN                NaN
# 17                NaN                NaN                NaN
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20                NaN                NaN                NaN
# 21                NaN                NaN                NaN
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
# 24           0.692857           0.737557           0.809578
# 25           0.692857           0.737557           0.809578
# 26           0.692857           0.737557           0.809578
# 27                NaN                NaN                NaN
# 28                NaN                NaN                NaN
# 29                NaN                NaN                NaN
# 30                NaN                NaN                NaN
# 31                NaN                NaN                NaN
# 32                NaN                NaN                NaN
# 33                NaN                NaN                NaN
# 34                NaN                NaN                NaN
# 35                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN                1
# 1                 NaN              NaN             NaN                1
# 2                 NaN              NaN             NaN                1
# 3                 NaN              NaN             NaN                1
# 4                 NaN              NaN             NaN                1
# 5                 NaN              NaN             NaN                1
# 6                 NaN              NaN             NaN                1
# 7                 NaN              NaN             NaN                1
# 8                 NaN              NaN             NaN                1
# 9                 NaN              NaN             NaN                1
# 10                NaN              NaN             NaN                1
# 11                NaN              NaN             NaN                1
# 12                NaN              NaN             NaN                1
# 13                NaN              NaN             NaN                1
# 14                NaN              NaN             NaN                1
# 15                NaN              NaN             NaN                1
# 16                NaN              NaN             NaN                1
# 17                NaN              NaN             NaN                1
# 18                NaN              NaN             NaN                1
# 19                NaN              NaN             NaN                1
# 20                NaN              NaN             NaN                1
# 21                NaN              NaN             NaN                1
# 22                NaN              NaN             NaN                1
# 23                NaN              NaN             NaN                1
# 24                NaN              NaN             NaN                1
# 25                NaN              NaN             NaN                1
# 26                NaN              NaN             NaN                1
# 27                NaN              NaN             NaN                1
# 28                NaN              NaN             NaN                1
# 29                NaN              NaN             NaN                1
# 30                NaN              NaN             NaN                1
# 31                NaN              NaN             NaN                1
# 32                NaN              NaN             NaN                1
# 33                NaN              NaN             NaN                1
# 34                NaN              NaN             NaN                1
# 35                NaN              NaN             NaN                1
