# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('Social_Network_Ads.csv')
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype='int')
dataset.drop('User ID',axis=1)
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
dataset['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
indep=dataset[['Gender_Male','Age','EstimatedSalary']]
dep=dataset[['Purchased']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=0.30,random_state=0)

# %%
from sklearn.naive_bayes import ComplementNB
from sklearn.model_selection import GridSearchCV
param_grid={'alpha':[0.001,0.01,1.0], 'force_alpha':[True,'bool'], 'fit_prior':[True,'bool'],'norm':[False,'bool']}
grid=GridSearchCV(ComplementNB(),param_grid,refit=True,verbose=3,n_jobs=-1,scoring='f1_weighted')
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 105 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'norm' parameter of ComplementNB must be an instance of 'bool' or an instance of 'numpy.bool_'. Got 'bool' instead.
#
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'force_alpha' parameter of ComplementNB must be an instance of 'bool' or an instance of 'numpy.bool_'. Got 'bool' instead.
#
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'fit_prior' parameter of ComplementNB must be an instance of 'bool' or an instance of 'numpy.bool_'. Got 'bool' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.53852366        nan        nan        nan        nan        nan
#         nan        nan 0.53852366        nan        nan        nan
#         nan        nan        nan        nan 0.53537651        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=ComplementNB(), n_jobs=-1,
#              param_grid={'alpha': [0.001, 0.01, 1.0],
#                          'fit_prior': [True, 'bool'],
#                          'force_alpha': [True, 'bool'],
#                          'norm': [False, 'bool']},
#              scoring='f1_weighted', verbose=3)

# %%
result=grid.cv_results_
grid_prediction=grid.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_prediction)
print('confusion matrix:\n',cm)
# Out:
# confusion matrix:
#  [[42 37]
#  [20 21]]

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(y_test,grid_prediction)
print('The clf report :\n',clf_report)
# Out:
# The clf report :
#                precision    recall  f1-score   support
#
#            0       0.68      0.53      0.60        79
#            1       0.36      0.51      0.42        41
#
#     accuracy                           0.53       120
#    macro avg       0.52      0.52      0.51       120
# weighted avg       0.57      0.52      0.54       120

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_prediction,average='weighted')
print('The f1_macro value for the best parameters {}:'.format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for the best parameters {'alpha': 0.001, 'fit_prior': True, 'force_alpha': True, 'norm': False}: 0.5371480765097786

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(x_test)[:,1])
# Out:
# 0.5158999691262736

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0        0.013591      0.001537         0.028570        0.001745       0.001
# 1        0.001233      0.001173         0.000000        0.000000       0.001
# 2        0.001880      0.000791         0.000000        0.000000       0.001
# 3        0.002773      0.003939         0.000000        0.000000       0.001
# 4        0.002487      0.002746         0.000000        0.000000       0.001
# 5        0.001635      0.002022         0.000000        0.000000       0.001
# 6        0.001705      0.003409         0.000000        0.000000       0.001
# 7        0.001324      0.001976         0.000000        0.000000       0.001
# 8        0.009052      0.001893         0.023209        0.008178        0.01
# 9        0.002106      0.004136         0.000000        0.000000        0.01
# 10       0.002003      0.004007         0.000000        0.000000        0.01
# 11       0.000492      0.000984         0.000000        0.000000        0.01
# 12       0.002221      0.003919         0.000000        0.000000        0.01
# 13       0.000503      0.001006         0.000000        0.000000        0.01
# 14       0.000228      0.000456         0.000000        0.000000        0.01
# 15       0.000643      0.001285         0.000000        0.000000        0.01
# 16       0.003061      0.003777         0.009842        0.000265         1.0
# 17       0.000000      0.000000         0.000000        0.000000         1.0
# 18       0.000000      0.000000         0.000000        0.000000         1.0
# 19       0.003351      0.002868         0.000000        0.000000         1.0
# 20       0.001607      0.001968         0.000000        0.000000         1.0
# 21       0.000000      0.000000         0.000000        0.000000         1.0
# 22       0.000000      0.000000         0.000000        0.000000         1.0
# 23       0.000000      0.000000         0.000000        0.000000         1.0
#
#    param_fit_prior param_force_alpha param_norm  \
# 0             True              True      False
# 1             True              True       bool
# 2             True              bool      False
# 3             True              bool       bool
# 4             bool              True      False
# 5             bool              True       bool
# 6             bool              bool      False
# 7             bool              bool       bool
# 8             True              True      False
# 9             True              True       bool
# 10            True              bool      False
# 11            True              bool       bool
# 12            bool              True      False
# 13            bool              True       bool
# 14            bool              bool      False
# 15            bool              bool       bool
# 16            True              True      False
# 17            True              True       bool
# 18            True              bool      False
# 19            True              bool       bool
# 20            bool              True      False
# 21            bool              True       bool
# 22            bool              bool      False
# 23            bool              bool       bool
#
#                                                params  split0_test_score  \
# 0   {'alpha': 0.001, 'fit_prior': True, 'force_alp...           0.527697
# 1   {'alpha': 0.001, 'fit_prior': True, 'force_alp...                NaN
# 2   {'alpha': 0.001, 'fit_prior': True, 'force_alp...                NaN
# 3   {'alpha': 0.001, 'fit_prior': True, 'force_alp...                NaN
# 4   {'alpha': 0.001, 'fit_prior': 'bool', 'force_a...                NaN
# 5   {'alpha': 0.001, 'fit_prior': 'bool', 'force_a...                NaN
# 6   {'alpha': 0.001, 'fit_prior': 'bool', 'force_a...                NaN
# 7   {'alpha': 0.001, 'fit_prior': 'bool', 'force_a...                NaN
# 8   {'alpha': 0.01, 'fit_prior': True, 'force_alph...           0.527697
# 9   {'alpha': 0.01, 'fit_prior': True, 'force_alph...                NaN
# 10  {'alpha': 0.01, 'fit_prior': True, 'force_alph...                NaN
# 11  {'alpha': 0.01, 'fit_prior': True, 'force_alph...                NaN
# 12  {'alpha': 0.01, 'fit_prior': 'bool', 'force_al...                NaN
# 13  {'alpha': 0.01, 'fit_prior': 'bool', 'force_al...                NaN
# 14  {'alpha': 0.01, 'fit_prior': 'bool', 'force_al...                NaN
# 15  {'alpha': 0.01, 'fit_prior': 'bool', 'force_al...                NaN
# 16  {'alpha': 1.0, 'fit_prior': True, 'force_alpha...           0.527697
# 17  {'alpha': 1.0, 'fit_prior': True, 'force_alpha...                NaN
# 18  {'alpha': 1.0, 'fit_prior': True, 'force_alpha...                NaN
# 19  {'alpha': 1.0, 'fit_prior': True, 'force_alpha...                NaN
# 20  {'alpha': 1.0, 'fit_prior': 'bool', 'force_alp...                NaN
# 21  {'alpha': 1.0, 'fit_prior': 'bool', 'force_alp...                NaN
# 22  {'alpha': 1.0, 'fit_prior': 'bool', 'force_alp...                NaN
# 23  {'alpha': 1.0, 'fit_prior': 'bool', 'force_alp...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.472527           0.555872           0.578065
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.472527           0.555872           0.578065
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14                NaN                NaN                NaN
# 15                NaN                NaN                NaN
# 16           0.472527           0.540136           0.578065
# 17                NaN                NaN                NaN
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20                NaN                NaN                NaN
# 21                NaN                NaN                NaN
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.558458         0.538524         0.03670                1
# 1                 NaN              NaN             NaN                4
# 2                 NaN              NaN             NaN                4
# 3                 NaN              NaN             NaN                4
# 4                 NaN              NaN             NaN                4
# 5                 NaN              NaN             NaN                4
# 6                 NaN              NaN             NaN                4
# 7                 NaN              NaN             NaN                4
# 8            0.558458         0.538524         0.03670                1
# 9                 NaN              NaN             NaN                4
# 10                NaN              NaN             NaN                4
# 11                NaN              NaN             NaN                4
# 12                NaN              NaN             NaN                4
# 13                NaN              NaN             NaN                4
# 14                NaN              NaN             NaN                4
# 15                NaN              NaN             NaN                4
# 16           0.558458         0.535377         0.03574                3
# 17                NaN              NaN             NaN                4
# 18                NaN              NaN             NaN                4
# 19                NaN              NaN             NaN                4
# 20                NaN              NaN             NaN                4
# 21                NaN              NaN             NaN                4
# 22                NaN              NaN             NaN                4
# 23                NaN              NaN             NaN                4
